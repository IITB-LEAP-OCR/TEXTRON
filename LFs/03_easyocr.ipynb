# %%
import os
import easyocr
import cv2
import matplotlib 
from matplotlib import pyplot as plt
import numpy as np
import io, json
# %matplotlib inline
IMAGE_PATH = "C:\\Projects\\Learn ML\\try_tatar_1702.07095.gz_paper10_revised4_withbib_15_ori.jpg"
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[481, 205], [605, 205], [605, 243], [481, 243]],
#   'dim( Voff >',
#   0.29853738894687176),
#  ([[639, 203], [723, 203], [723, 245], [639, 245]],
#   'LG(C1',
#   0.24656978757148978),
#  ([[763, 205], [851, 205], [851, 245], [763, 245]],
#   'HG (C1',
#   0.4319458722347302),
#  ([[891, 203], [933, 203], [933, 245], [891, 245]], 'Lg', 0.09643333293523106),
#  ([[1015, 205], [1103, 205], [1103, 243], [1015, 243]],
#   'HS (C2_',
#   0.33843953670265897),
#  ([[1143, 203], [1279, 203], [1279, 241], [1143, 241]],
#   'He (C1,C2_',
#   0.7919160273469907),
#  ([[612, 246], [898, 246], [898, 278], [612, 278]],
#   'Standard GmsFEM',
#   0.790350873288188),
#  ([[915, 245], [1089, 245], [1089, 283], [915, 283]],
#   'un-coupled)',
#   0.8843144496987669),
#  ([[512, 288], [584, 288], [584, 320], [512, 320]],
#   '1452',
#   0.9999819272076395),
#  ([[647, 287], [729, 287], [729, 323], [647, 323]],
#   '0.837',
# ...

# %%
text = result[0][1]
img = cv2.imread(IMAGE_PATH)
i = 0
plt.figure(figsize=(20,20))
#plt.imshow(img)
for (Dimensions,Word,Conf) in result:
    # top_left = tuple(result[i][0][0])
    # bottom_right = tuple(result[i][0][2])
    TopL = tuple(Dimensions[0])
    BottomR = tuple(Dimensions[2])
    TopL = (int(TopL[0]),int(TopL[1]))
    BottomR = (int(BottomR[0]),int(BottomR[1]))
    img = cv2.rectangle(img, TopL, BottomR, (255,0,0),2)
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()
display(Dimensions[1])
# Out:
# [1030.968405784864, 1509.4982475444424]

# %%
text = result[0][1]
img = cv2.imread(IMAGE_PATH)
i = 0
plt.figure(figsize=(20,20))
plt.imshow(img)
while i < len(result):
    top_left = tuple(result[i][0][0])
    bottom_right = tuple(result[i][0][2])
    img = cv2.rectangle(img,top_left,bottom_right, (0,255,0),3)
    i = i+1
    #plt.figure(figsize=(20,20))
    plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Projects\Learn ML\Cloud_Vision_IITB\easyocr.ipynb Cell 2 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Projects/Learn%20ML/Cloud_Vision_IITB/easyocr.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> top_left = tuple(result[i][0][0])
#       <a href='vscode-notebook-cell:/c%3A/Projects/Learn%20ML/Cloud_Vision_IITB/easyocr.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> bottom_right = tuple(result[i][0][2])
# ----> <a href='vscode-notebook-cell:/c%3A/Projects/Learn%20ML/Cloud_Vision_IITB/easyocr.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> img = cv2.rectangle(img,top_left,bottom_right, (0,255,0),3)
#      <a href='vscode-notebook-cell:/c%3A/Projects/Learn%20ML/Cloud_Vision_IITB/easyocr.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> i = i+1
# ...
