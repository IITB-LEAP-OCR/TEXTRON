# %% [markdown]
# ### Imports

# %%
import os
import cv2
import pickle
from tqdm import tqdm
import numpy as np
import pandas as pd

from skimage import io, color, filters, morphology
from skimage.util import invert
from skimage.filters import threshold_otsu
from skimage.morphology import convex_hull_image
from skimage.feature import canny
from scipy import ndimage as ndi

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Functions

# %%
def pure_binarize(image):
    thresh = threshold_otsu(image)
    image = image > thresh
    return image    


def binarize_image(image):
    image = color.rgb2gray(image)
    thresh = threshold_otsu(image)
    image = image > thresh
    return image


def get_bboxes(img, file, input_dir, output_dir, output_txt_dir, width_threshold, height_threshold):

    img = invert(img)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, binary = cv2.threshold(gray, 100, 255, cv2.THRESH_OTSU)
    inverted_binary = ~binary
    width, height = inverted_binary.shape
    contours, hierarchy = cv2.findContours(inverted_binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    bboxes = []
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        w = int(w*(1/WIDTH_THRESHOLD))
        h = int(h*(1/HEIGHT_THRESHOLD))
        if cv2.contourArea(c) > 30:
            bboxes.append(['text',1,x, y, w, h])

    final_img = cv2.imread(input_dir + file)
    for b in bboxes:
        x = b[2]
        y = b[3]
        w = int(b[4])
        h = int(b[5])
        cv2.rectangle(final_img,(x,y), (x+w,y+h), (0, 255, 0),1)

    df = pd.DataFrame(bboxes, columns = ['label', 'confidence', 'X', 'Y', 'W', 'H'])
    name = file[:len(file) - 4]
    io.imsave(output_dir + name + '_pred.jpg', final_img)
    df.to_csv(output_txt_dir + name + '.txt', sep=' ',index=False, header=False)


def get_boxes(image, width_threshold, height_threshold, thickness=4, type="double"):

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, binary = cv2.threshold(gray, 100, 255, cv2.THRESH_OTSU)
    inverted_binary = ~binary
    width, height = inverted_binary.shape
    contours, hierarchy = cv2.findContours(inverted_binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    if(type == "double"):
        with_contours_int = cv2.drawContours(image, contours, -1,(0,0,255),thickness)
        gray_contour = cv2.cvtColor(with_contours_int, cv2.COLOR_BGR2GRAY)
        ret, binary_contour = cv2.threshold(gray_contour, 100, 255, cv2.THRESH_OTSU)
        inverted_contour = ~binary_contour
        contours, hierarchy = cv2.findContours(inverted_contour, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    bboxes = []
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        
#         if (w < width/2): #For English DocBank use the below one
        if (cv2.contourArea(c)) > (width*height)/100000 and h<(height/4) and (w < width/2): # For multilingual
            bboxes.append([x, y, w, h])

    final_img = np.zeros((image.shape), dtype = np.uint8)
    for b in bboxes:
        x = b[0]
        y = b[1]
        w = int(b[2]*width_threshold)
        h = int(b[3]*height_threshold)
        cv2.rectangle(final_img,(x,y), (x+w,y+h), (255, 255, 255),-1)
    final_img = ~final_img
    final_img = binarize_image(final_img)
    final_img = final_img*1
    return final_img


def get_image_edges(image, width_threshold, height_threshold, thickness=4, value="double"):
    image = binarize_image(image)
    image = invert(image)
    edges = filters.sobel(image)
    edges = pure_binarize(edges)
    io.imsave("temp.jpg", edges)
    image = cv2.imread("temp.jpg")
    return get_boxes(image, width_threshold, height_threshold, thickness, value)


def get_pillow_image_edges(image, width_threshold, height_threshold):
    image = image.convert("L")    # Converting Image to Gray
    edges = image.filter(ImageFilter.FIND_EDGES)
    edges = np.array(edges)
    edges = pure_binarize(edges)
    io.imsave("temp.jpg", edges)
    image = cv2.imread("temp.jpg")
    return get_boxes(image, width_threshold, height_threshold, "single")


def get_segmentation_labels(image, width_threshold, height_threshold, thickness=4, value="double"):
    image = binarize_image(image)
    edges = canny(image)
    image = ndi.binary_fill_holes(edges)
    image = pure_binarize(image)
    io.imsave("temp.jpg", image)
    image = cv2.imread("temp.jpg")
    return get_boxes(image, width_threshold, height_threshold, thickness, value)


def get_contour_labels(image, width_threshold, height_threshold, thickness=4, value="single"):
    return get_boxes(image, width_threshold, height_threshold, thickness, value)

# %% [markdown]
# ### Contour Based LF

# %%
input_img_dir = './../../processed/docbank_100/images/' 
output_txt_dir = './../../results/LF_latest/contour/txt/'
output_img_dir = './../../results/LF_latest/contour/images/'
output_pix_dir = './../../results/LFs/contour/pixel/'


dir_list = os.listdir(input_img_dir)

WIDTH_THRESHOLD = 1
HEIGHT_THRESHOLD = 1

for file in tqdm(dir_list):
    out_img_file = output_img_dir + file
    ori_img = cv2.imread(input_img_dir + file)
    image = get_contour_labels(ori_img, WIDTH_THRESHOLD, HEIGHT_THRESHOLD, thickness=4, value="double")
    io.imsave("temp.jpg", image)
    image = cv2.imread("temp.jpg")
    get_bboxes(image, file, input_img_dir, output_img_dir, output_txt_dir, WIDTH_THRESHOLD, HEIGHT_THRESHOLD)
# Out:
#   0%|                                                                                                                                                                                         | 0/100 [00:00<?, ?it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|█▊                                                                                                                                                                               | 1/100 [00:00<00:41,  2.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|███▌                                                                                                                                                                             | 2/100 [00:00<00:38,  2.54it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   3%|█████▎                                                                                                                                                                           | 3/100 [00:01<00:37,  2.58it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|███████                                                                                                                                                                          | 4/100 [00:01<00:37,  2.56it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   5%|████████▊                                                                                                                                                                        | 5/100 [00:01<00:37,  2.51it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|██████████▌                                                                                                                                                                      | 6/100 [00:02<00:37,  2.50it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   7%|████████████▍                                                                                                                                                                    | 7/100 [00:02<00:38,  2.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|██████████████▏                                                                                                                                                                  | 8/100 [00:03<00:32,  2.82it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   9%|███████████████▉                                                                                                                                                                 | 9/100 [00:03<00:32,  2.79it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█████████████████▌                                                                                                                                                              | 10/100 [00:03<00:36,  2.47it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  11%|███████████████████▎                                                                                                                                                            | 11/100 [00:04<00:38,  2.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█████████████████████                                                                                                                                                           | 12/100 [00:04<00:38,  2.29it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  13%|██████████████████████▉                                                                                                                                                         | 13/100 [00:05<00:39,  2.23it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  14%|████████████████████████▋                                                                                                                                                       | 14/100 [00:05<00:36,  2.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  15%|██████████████████████████▍                                                                                                                                                     | 15/100 [00:06<00:34,  2.47it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  16%|████████████████████████████▏                                                                                                                                                   | 16/100 [00:06<00:34,  2.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  17%|█████████████████████████████▉                                                                                                                                                  | 17/100 [00:06<00:35,  2.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  18%|███████████████████████████████▋                                                                                                                                                | 18/100 [00:07<00:34,  2.35it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  19%|█████████████████████████████████▍                                                                                                                                              | 19/100 [00:07<00:34,  2.32it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  20%|███████████████████████████████████▏                                                                                                                                            | 20/100 [00:08<00:33,  2.36it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  21%|████████████████████████████████████▉                                                                                                                                           | 21/100 [00:08<00:33,  2.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  22%|██████████████████████████████████████▋                                                                                                                                         | 22/100 [00:09<00:32,  2.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  23%|████████████████████████████████████████▍                                                                                                                                       | 23/100 [00:09<00:31,  2.46it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  24%|██████████████████████████████████████████▏                                                                                                                                     | 24/100 [00:10<00:34,  2.21it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  25%|████████████████████████████████████████████                                                                                                                                    | 25/100 [00:10<00:36,  2.06it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  26%|█████████████████████████████████████████████▊                                                                                                                                  | 26/100 [00:11<00:35,  2.09it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  27%|███████████████████████████████████████████████▌                                                                                                                                | 27/100 [00:11<00:35,  2.03it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  28%|█████████████████████████████████████████████████▎                                                                                                                              | 28/100 [00:12<00:35,  2.05it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  29%|███████████████████████████████████████████████████                                                                                                                             | 29/100 [00:12<00:33,  2.11it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|████████████████████████████████████████████████████▊                                                                                                                           | 30/100 [00:12<00:29,  2.33it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  31%|██████████████████████████████████████████████████████▌                                                                                                                         | 31/100 [00:13<00:28,  2.43it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  32%|████████████████████████████████████████████████████████▎                                                                                                                       | 32/100 [00:13<00:27,  2.43it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  33%|██████████████████████████████████████████████████████████                                                                                                                      | 33/100 [00:13<00:26,  2.54it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  34%|███████████████████████████████████████████████████████████▊                                                                                                                    | 34/100 [00:14<00:26,  2.48it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  35%|█████████████████████████████████████████████████████████████▌                                                                                                                  | 35/100 [00:14<00:25,  2.56it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  36%|███████████████████████████████████████████████████████████████▎                                                                                                                | 36/100 [00:15<00:24,  2.59it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  37%|█████████████████████████████████████████████████████████████████                                                                                                               | 37/100 [00:15<00:24,  2.62it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  38%|██████████████████████████████████████████████████████████████████▉                                                                                                             | 38/100 [00:15<00:23,  2.61it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  39%|████████████████████████████████████████████████████████████████████▋                                                                                                           | 39/100 [00:16<00:23,  2.59it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  40%|██████████████████████████████████████████████████████████████████████▍                                                                                                         | 40/100 [00:16<00:22,  2.63it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  41%|████████████████████████████████████████████████████████████████████████▏                                                                                                       | 41/100 [00:16<00:21,  2.70it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  42%|█████████████████████████████████████████████████████████████████████████▉                                                                                                      | 42/100 [00:17<00:21,  2.75it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  43%|███████████████████████████████████████████████████████████████████████████▋                                                                                                    | 43/100 [00:17<00:20,  2.77it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  44%|█████████████████████████████████████████████████████████████████████████████▍                                                                                                  | 44/100 [00:18<00:22,  2.52it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  45%|███████████████████████████████████████████████████████████████████████████████▏                                                                                                | 45/100 [00:18<00:21,  2.62it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  46%|████████████████████████████████████████████████████████████████████████████████▉                                                                                               | 46/100 [00:18<00:21,  2.51it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  47%|██████████████████████████████████████████████████████████████████████████████████▋                                                                                             | 47/100 [00:19<00:20,  2.54it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  48%|████████████████████████████████████████████████████████████████████████████████████▍                                                                                           | 48/100 [00:19<00:19,  2.68it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  49%|██████████████████████████████████████████████████████████████████████████████████████▏                                                                                         | 49/100 [00:19<00:19,  2.68it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  50%|████████████████████████████████████████████████████████████████████████████████████████                                                                                        | 50/100 [00:20<00:18,  2.65it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  51%|█████████████████████████████████████████████████████████████████████████████████████████▊                                                                                      | 51/100 [00:20<00:17,  2.72it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▌                                                                                    | 52/100 [00:21<00:18,  2.55it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  53%|█████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                  | 53/100 [00:21<00:18,  2.53it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  54%|███████████████████████████████████████████████████████████████████████████████████████████████                                                                                 | 54/100 [00:21<00:16,  2.73it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  55%|████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                               | 55/100 [00:22<00:17,  2.53it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                             | 56/100 [00:22<00:16,  2.59it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  57%|████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                           | 57/100 [00:23<00:15,  2.70it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  58%|██████████████████████████████████████████████████████████████████████████████████████████████████████                                                                          | 58/100 [00:23<00:15,  2.68it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  59%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                        | 59/100 [00:23<00:14,  2.74it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  60%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                      | 60/100 [00:24<00:15,  2.54it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  61%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                    | 61/100 [00:24<00:15,  2.54it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  62%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                   | 62/100 [00:25<00:15,  2.50it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  63%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                 | 63/100 [00:25<00:14,  2.49it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                               | 64/100 [00:25<00:15,  2.28it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  65%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                             | 65/100 [00:26<00:14,  2.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  66%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                           | 66/100 [00:26<00:14,  2.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  67%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                          | 67/100 [00:27<00:14,  2.35it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                        | 68/100 [00:27<00:13,  2.30it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  69%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                      | 69/100 [00:28<00:12,  2.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                    | 70/100 [00:28<00:11,  2.54it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  71%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                   | 71/100 [00:28<00:11,  2.54it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                 | 72/100 [00:29<00:10,  2.57it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  73%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                               | 73/100 [00:29<00:10,  2.57it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                             | 74/100 [00:29<00:09,  2.63it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                            | 75/100 [00:30<00:09,  2.50it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                          | 76/100 [00:30<00:09,  2.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  77%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                        | 77/100 [00:31<00:09,  2.45it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                      | 78/100 [00:31<00:09,  2.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                     | 79/100 [00:31<00:08,  2.53it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                   | 80/100 [00:32<00:07,  2.64it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                 | 81/100 [00:32<00:07,  2.51it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                               | 82/100 [00:33<00:07,  2.53it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                              | 83/100 [00:33<00:06,  2.56it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                            | 84/100 [00:34<00:06,  2.38it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                          | 85/100 [00:34<00:06,  2.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                        | 86/100 [00:34<00:05,  2.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  87%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                       | 87/100 [00:35<00:05,  2.48it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                     | 88/100 [00:35<00:05,  2.35it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                   | 89/100 [00:36<00:04,  2.27it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 90/100 [00:36<00:04,  2.38it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 91/100 [00:36<00:03,  2.30it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉              | 92/100 [00:37<00:03,  2.33it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋            | 93/100 [00:37<00:03,  2.32it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍          | 94/100 [00:38<00:02,  2.36it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 95/100 [00:38<00:02,  2.32it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉       | 96/100 [00:39<00:01,  2.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋     | 97/100 [00:39<00:01,  1.96it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 98/100 [00:40<00:01,  1.97it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 99/100 [00:40<00:00,  2.07it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:41<00:00,  2.43it/s]

# %% [markdown]
# ### Edges Based LF

# %%
input_img_dir = './../../processed/docbank_100/images/' 
output_txt_dir = './../../results/LF_latest/edges/txt/'
output_img_dir = './../../results/LF_latest/edges/images/'


dir_list = os.listdir(input_img_dir)

WIDTH_THRESHOLD = 1
HEIGHT_THRESHOLD = 1

for file in tqdm(dir_list):
    if(file=='275.tar_1809.08252.gz_PapierFluctuations3_0_pro.jpg'):
    out_img_file = output_img_dir + file
    ori_img = cv2.imread(input_img_dir + file)
    image = get_image_edges(ori_img, WIDTH_THRESHOLD, HEIGHT_THRESHOLD, thickness=4, value="single")
    io.imsave("temp.jpg", image)
    image = cv2.imread("temp.jpg")
    get_bboxes(image, file, input_img_dir, output_img_dir, output_txt_dir, WIDTH_THRESHOLD, HEIGHT_THRESHOLD)
# Out:
#   0%|                                                                                                                                                                                         | 0/100 [00:00<?, ?it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|█▊                                                                                                                                                                               | 1/100 [00:00<01:25,  1.16it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|███▌                                                                                                                                                                             | 2/100 [00:01<01:19,  1.24it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   3%|█████▎                                                                                                                                                                           | 3/100 [00:02<01:12,  1.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|███████                                                                                                                                                                          | 4/100 [00:02<01:08,  1.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   5%|████████▊                                                                                                                                                                        | 5/100 [00:03<01:08,  1.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|██████████▌                                                                                                                                                                      | 6/100 [00:04<01:07,  1.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   7%|████████████▍                                                                                                                                                                    | 7/100 [00:05<01:08,  1.36it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|██████████████▏                                                                                                                                                                  | 8/100 [00:05<00:56,  1.63it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   9%|███████████████▉                                                                                                                                                                 | 9/100 [00:06<00:58,  1.56it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█████████████████▌                                                                                                                                                              | 10/100 [00:07<01:02,  1.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  11%|███████████████████▎                                                                                                                                                            | 11/100 [00:07<01:04,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█████████████████████                                                                                                                                                           | 12/100 [00:08<01:04,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  13%|██████████████████████▉                                                                                                                                                         | 13/100 [00:09<01:03,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  14%|████████████████████████▋                                                                                                                                                       | 14/100 [00:09<00:59,  1.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  15%|██████████████████████████▍                                                                                                                                                     | 15/100 [00:10<00:56,  1.50it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  16%|████████████████████████████▏                                                                                                                                                   | 16/100 [00:11<00:57,  1.45it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  17%|█████████████████████████████▉                                                                                                                                                  | 17/100 [00:12<00:59,  1.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  18%|███████████████████████████████▋                                                                                                                                                | 18/100 [00:12<00:58,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  19%|█████████████████████████████████▍                                                                                                                                              | 19/100 [00:13<00:56,  1.43it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  20%|███████████████████████████████████▏                                                                                                                                            | 20/100 [00:14<00:55,  1.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  21%|████████████████████████████████████▉                                                                                                                                           | 21/100 [00:14<00:56,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  22%|██████████████████████████████████████▋                                                                                                                                         | 22/100 [00:15<00:55,  1.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  23%|████████████████████████████████████████▍                                                                                                                                       | 23/100 [00:16<00:54,  1.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  24%|██████████████████████████████████████████▏                                                                                                                                     | 24/100 [00:16<00:51,  1.47it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  25%|████████████████████████████████████████████                                                                                                                                    | 25/100 [00:17<00:49,  1.51it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  26%|█████████████████████████████████████████████▊                                                                                                                                  | 26/100 [00:18<00:48,  1.52it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  27%|███████████████████████████████████████████████▌                                                                                                                                | 27/100 [00:18<00:51,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  28%|█████████████████████████████████████████████████▎                                                                                                                              | 28/100 [00:19<00:50,  1.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  29%|███████████████████████████████████████████████████                                                                                                                             | 29/100 [00:20<00:50,  1.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|████████████████████████████████████████████████████▊                                                                                                                           | 30/100 [00:21<00:48,  1.45it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  31%|██████████████████████████████████████████████████████▌                                                                                                                         | 31/100 [00:21<00:48,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  32%|████████████████████████████████████████████████████████▎                                                                                                                       | 32/100 [00:22<00:50,  1.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  33%|██████████████████████████████████████████████████████████                                                                                                                      | 33/100 [00:23<00:50,  1.32it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  34%|███████████████████████████████████████████████████████████▊                                                                                                                    | 34/100 [00:24<00:49,  1.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  35%|█████████████████████████████████████████████████████████████▌                                                                                                                  | 35/100 [00:24<00:49,  1.32it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  36%|███████████████████████████████████████████████████████████████▎                                                                                                                | 36/100 [00:25<00:47,  1.36it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  37%|█████████████████████████████████████████████████████████████████                                                                                                               | 37/100 [00:26<00:45,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  38%|██████████████████████████████████████████████████████████████████▉                                                                                                             | 38/100 [00:27<00:45,  1.36it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  39%|████████████████████████████████████████████████████████████████████▋                                                                                                           | 39/100 [00:27<00:47,  1.29it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  40%|██████████████████████████████████████████████████████████████████████▍                                                                                                         | 40/100 [00:28<00:47,  1.27it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  41%|████████████████████████████████████████████████████████████████████████▏                                                                                                       | 41/100 [00:29<00:48,  1.21it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  42%|█████████████████████████████████████████████████████████████████████████▉                                                                                                      | 42/100 [00:30<00:45,  1.28it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  43%|███████████████████████████████████████████████████████████████████████████▋                                                                                                    | 43/100 [00:30<00:41,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  44%|█████████████████████████████████████████████████████████████████████████████▍                                                                                                  | 44/100 [00:31<00:40,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  45%|███████████████████████████████████████████████████████████████████████████████▏                                                                                                | 45/100 [00:32<00:38,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  46%|████████████████████████████████████████████████████████████████████████████████▉                                                                                               | 46/100 [00:33<00:37,  1.43it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  47%|██████████████████████████████████████████████████████████████████████████████████▋                                                                                             | 47/100 [00:33<00:36,  1.46it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  48%|████████████████████████████████████████████████████████████████████████████████████▍                                                                                           | 48/100 [00:34<00:35,  1.45it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  49%|██████████████████████████████████████████████████████████████████████████████████████▏                                                                                         | 49/100 [00:35<00:34,  1.47it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  50%|████████████████████████████████████████████████████████████████████████████████████████                                                                                        | 50/100 [00:35<00:34,  1.43it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  51%|█████████████████████████████████████████████████████████████████████████████████████████▊                                                                                      | 51/100 [00:36<00:35,  1.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▌                                                                                    | 52/100 [00:37<00:35,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  53%|█████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                  | 53/100 [00:38<00:34,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  54%|███████████████████████████████████████████████████████████████████████████████████████████████                                                                                 | 54/100 [00:38<00:32,  1.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  55%|████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                               | 55/100 [00:39<00:32,  1.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                             | 56/100 [00:40<00:31,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  57%|████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                           | 57/100 [00:40<00:29,  1.48it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  58%|██████████████████████████████████████████████████████████████████████████████████████████████████████                                                                          | 58/100 [00:41<00:29,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  59%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                        | 59/100 [00:42<00:28,  1.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  60%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                      | 60/100 [00:42<00:29,  1.38it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  61%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                    | 61/100 [00:43<00:28,  1.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  62%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                   | 62/100 [00:44<00:27,  1.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  63%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                 | 63/100 [00:45<00:27,  1.36it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                               | 64/100 [00:46<00:28,  1.25it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  65%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                             | 65/100 [00:46<00:26,  1.32it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  66%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                           | 66/100 [00:47<00:24,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  67%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                          | 67/100 [00:48<00:25,  1.32it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                        | 68/100 [00:49<00:24,  1.29it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  69%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                      | 69/100 [00:49<00:23,  1.33it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                    | 70/100 [00:50<00:21,  1.38it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  71%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                   | 71/100 [00:51<00:20,  1.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                 | 72/100 [00:51<00:19,  1.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  73%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                               | 73/100 [00:52<00:18,  1.45it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                             | 74/100 [00:53<00:17,  1.45it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                            | 75/100 [00:53<00:17,  1.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                          | 76/100 [00:54<00:16,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  77%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                        | 77/100 [00:55<00:16,  1.42it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                      | 78/100 [00:56<00:18,  1.22it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                     | 79/100 [00:57<00:17,  1.22it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                   | 80/100 [00:58<00:16,  1.20it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                 | 81/100 [00:58<00:16,  1.18it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                               | 82/100 [00:59<00:14,  1.25it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                              | 83/100 [01:00<00:13,  1.30it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                            | 84/100 [01:01<00:11,  1.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                          | 85/100 [01:01<00:11,  1.36it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                        | 86/100 [01:02<00:10,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  87%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                       | 87/100 [01:03<00:09,  1.38it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                     | 88/100 [01:04<00:09,  1.29it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                   | 89/100 [01:04<00:08,  1.29it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 90/100 [01:05<00:07,  1.35it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 91/100 [01:06<00:06,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉              | 92/100 [01:06<00:05,  1.41it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋            | 93/100 [01:07<00:05,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍          | 94/100 [01:08<00:04,  1.34it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 95/100 [01:09<00:03,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉       | 96/100 [01:09<00:02,  1.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋     | 97/100 [01:10<00:02,  1.35it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 98/100 [01:11<00:01,  1.37it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 99/100 [01:11<00:00,  1.40it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:12<00:00,  1.38it/s]

# %% [markdown]
# ### Segment Based LF

# %%
input_img_dir = './../../processed/docbank_100/images/' 
output_txt_dir = './../../results/LF_latest/segment/txt/'
output_img_dir = './../../results/LF_latest/segment/images/'


dir_list = os.listdir(input_img_dir)

WIDTH_THRESHOLD = 1
HEIGHT_THRESHOLD = 1

for file in tqdm(dir_list):
    out_img_file = output_img_dir + file
    ori_img = cv2.imread(input_img_dir + file)
    image = get_segmentation_labels(ori_img, WIDTH_THRESHOLD, HEIGHT_THRESHOLD, thickness=4, value="single")
    io.imsave("temp.jpg", image)
    image = cv2.imread("temp.jpg")
    get_bboxes(image, file, input_img_dir, output_img_dir, output_txt_dir, WIDTH_THRESHOLD, HEIGHT_THRESHOLD)
# Out:
#   0%|                                                                                                                                                                                         | 0/100 [00:00<?, ?it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|█▊                                                                                                                                                                               | 1/100 [00:01<01:44,  1.06s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|███▌                                                                                                                                                                             | 2/100 [00:02<01:41,  1.04s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   3%|█████▎                                                                                                                                                                           | 3/100 [00:03<01:37,  1.01s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|███████                                                                                                                                                                          | 4/100 [00:04<01:38,  1.03s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   5%|████████▊                                                                                                                                                                        | 5/100 [00:05<01:42,  1.08s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|██████████▌                                                                                                                                                                      | 6/100 [00:06<01:40,  1.07s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   7%|████████████▍                                                                                                                                                                    | 7/100 [00:07<01:47,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|██████████████▏                                                                                                                                                                  | 8/100 [00:08<01:30,  1.01it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   9%|███████████████▉                                                                                                                                                                 | 9/100 [00:09<01:31,  1.01s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█████████████████▌                                                                                                                                                              | 10/100 [00:10<01:43,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  11%|███████████████████▎                                                                                                                                                            | 11/100 [00:12<01:44,  1.17s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█████████████████████                                                                                                                                                           | 12/100 [00:13<01:44,  1.19s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  13%|██████████████████████▉                                                                                                                                                         | 13/100 [00:14<01:46,  1.23s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  14%|████████████████████████▋                                                                                                                                                       | 14/100 [00:15<01:38,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  15%|██████████████████████████▍                                                                                                                                                     | 15/100 [00:16<01:34,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  16%|████████████████████████████▏                                                                                                                                                   | 16/100 [00:17<01:37,  1.16s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  17%|█████████████████████████████▉                                                                                                                                                  | 17/100 [00:18<01:35,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  18%|███████████████████████████████▋                                                                                                                                                | 18/100 [00:20<01:33,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  19%|█████████████████████████████████▍                                                                                                                                              | 19/100 [00:21<01:32,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  20%|███████████████████████████████████▏                                                                                                                                            | 20/100 [00:22<01:28,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  21%|████████████████████████████████████▉                                                                                                                                           | 21/100 [00:23<01:27,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  22%|██████████████████████████████████████▋                                                                                                                                         | 22/100 [00:24<01:28,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  23%|████████████████████████████████████████▍                                                                                                                                       | 23/100 [00:25<01:26,  1.13s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  24%|██████████████████████████████████████████▏                                                                                                                                     | 24/100 [00:26<01:24,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  25%|████████████████████████████████████████████                                                                                                                                    | 25/100 [00:27<01:20,  1.08s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  26%|█████████████████████████████████████████████▊                                                                                                                                  | 26/100 [00:28<01:21,  1.10s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  27%|███████████████████████████████████████████████▌                                                                                                                                | 27/100 [00:30<01:27,  1.19s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  28%|█████████████████████████████████████████████████▎                                                                                                                              | 28/100 [00:31<01:25,  1.19s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  29%|███████████████████████████████████████████████████                                                                                                                             | 29/100 [00:32<01:24,  1.19s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|████████████████████████████████████████████████████▊                                                                                                                           | 30/100 [00:33<01:19,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  31%|██████████████████████████████████████████████████████▌                                                                                                                         | 31/100 [00:34<01:18,  1.13s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  32%|████████████████████████████████████████████████████████▎                                                                                                                       | 32/100 [00:36<01:18,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  33%|██████████████████████████████████████████████████████████                                                                                                                      | 33/100 [00:37<01:16,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  34%|███████████████████████████████████████████████████████████▊                                                                                                                    | 34/100 [00:38<01:15,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  35%|█████████████████████████████████████████████████████████████▌                                                                                                                  | 35/100 [00:39<01:12,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  36%|███████████████████████████████████████████████████████████████▎                                                                                                                | 36/100 [00:40<01:07,  1.06s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  37%|█████████████████████████████████████████████████████████████████                                                                                                               | 37/100 [00:41<01:10,  1.13s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  38%|██████████████████████████████████████████████████████████████████▉                                                                                                             | 38/100 [00:42<01:11,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  39%|████████████████████████████████████████████████████████████████████▋                                                                                                           | 39/100 [00:43<01:09,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  40%|██████████████████████████████████████████████████████████████████████▍                                                                                                         | 40/100 [00:44<01:07,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  41%|████████████████████████████████████████████████████████████████████████▏                                                                                                       | 41/100 [00:46<01:06,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  42%|█████████████████████████████████████████████████████████████████████████▉                                                                                                      | 42/100 [00:47<01:03,  1.09s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  43%|███████████████████████████████████████████████████████████████████████████▋                                                                                                    | 43/100 [00:48<01:01,  1.07s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  44%|█████████████████████████████████████████████████████████████████████████████▍                                                                                                  | 44/100 [00:49<01:03,  1.13s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  45%|███████████████████████████████████████████████████████████████████████████████▏                                                                                                | 45/100 [00:50<00:59,  1.09s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  46%|████████████████████████████████████████████████████████████████████████████████▉                                                                                               | 46/100 [00:51<01:00,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  47%|██████████████████████████████████████████████████████████████████████████████████▋                                                                                             | 47/100 [00:52<00:58,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  48%|████████████████████████████████████████████████████████████████████████████████████▍                                                                                           | 48/100 [00:53<00:55,  1.07s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  49%|██████████████████████████████████████████████████████████████████████████████████████▏                                                                                         | 49/100 [00:54<00:53,  1.06s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  50%|████████████████████████████████████████████████████████████████████████████████████████                                                                                        | 50/100 [00:55<00:54,  1.09s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  51%|█████████████████████████████████████████████████████████████████████████████████████████▊                                                                                      | 51/100 [00:56<00:52,  1.07s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▌                                                                                    | 52/100 [00:58<00:54,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  53%|█████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                  | 53/100 [00:59<00:55,  1.17s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  54%|███████████████████████████████████████████████████████████████████████████████████████████████                                                                                 | 54/100 [01:00<00:49,  1.08s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  55%|████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                               | 55/100 [01:01<00:50,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                             | 56/100 [01:02<00:48,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  57%|████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                           | 57/100 [01:03<00:46,  1.09s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  58%|██████████████████████████████████████████████████████████████████████████████████████████████████████                                                                          | 58/100 [01:04<00:46,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  59%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                        | 59/100 [01:05<00:44,  1.07s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  60%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                      | 60/100 [01:07<00:46,  1.16s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  61%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                    | 61/100 [01:08<00:44,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  62%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                   | 62/100 [01:09<00:43,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  63%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                 | 63/100 [01:10<00:41,  1.13s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                               | 64/100 [01:11<00:43,  1.20s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  65%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                             | 65/100 [01:12<00:41,  1.18s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  66%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                           | 66/100 [01:14<00:39,  1.16s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  67%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                          | 67/100 [01:15<00:39,  1.19s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                        | 68/100 [01:16<00:38,  1.21s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  69%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                      | 69/100 [01:17<00:35,  1.16s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                    | 70/100 [01:18<00:33,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  71%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                   | 71/100 [01:19<00:32,  1.10s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                 | 72/100 [01:20<00:29,  1.07s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  73%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                               | 73/100 [01:21<00:28,  1.06s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                             | 74/100 [01:22<00:26,  1.02s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                            | 75/100 [01:23<00:27,  1.09s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                          | 76/100 [01:25<00:26,  1.11s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  77%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                        | 77/100 [01:26<00:25,  1.10s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                      | 78/100 [01:27<00:24,  1.13s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                     | 79/100 [01:28<00:22,  1.06s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                   | 80/100 [01:29<00:20,  1.02s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                 | 81/100 [01:30<00:19,  1.03s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                               | 82/100 [01:31<00:18,  1.05s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                              | 83/100 [01:32<00:18,  1.09s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                            | 84/100 [01:33<00:18,  1.13s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                          | 85/100 [01:34<00:17,  1.16s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                        | 86/100 [01:36<00:16,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  87%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                       | 87/100 [01:37<00:14,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                     | 88/100 [01:38<00:14,  1.19s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                   | 89/100 [01:39<00:13,  1.20s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 90/100 [01:40<00:11,  1.18s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 91/100 [01:42<00:10,  1.17s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉              | 92/100 [01:43<00:09,  1.15s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋            | 93/100 [01:44<00:08,  1.17s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍          | 94/100 [01:45<00:06,  1.16s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 95/100 [01:46<00:05,  1.14s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉       | 96/100 [01:47<00:04,  1.07s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋     | 97/100 [01:48<00:03,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 98/100 [01:49<00:02,  1.12s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 99/100 [01:50<00:01,  1.08s/it]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:51<00:00,  1.12s/it]

# %% [markdown]
# ### DocTR LF

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

model = ocr_predictor(pretrained=True)

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

model = ocr_predictor(pretrained=True)

input_dir   = './../../processed/docbank_100/images/'
output_dir  = './../../data/00_docbank_100/doctr/'

input_dir   = './../../funsd/testing_data/images/'
output_dir  = './../../data/06_funsd/doctr/'

dir_list = os.listdir(input_dir)
results = {}
images = []

for image in tqdm(dir_list):
    doc = DocumentFile.from_images(input_dir+image)
    result = model(doc)
    results[image] = result
    images.append(image)
    
# with open(output_dir + 'results.pkl', 'rb') as f:
#     results = pickle.load(f)
    
# for i in range(len(results)):
#     results[i].show(docs[i])

dimensions = {}
total = {}
for image,result in tqdm(results.items()):
    dim = tuple(reversed(result.pages[0].dimensions))
    predictions = []
    img = io.imread(os.path.join(input_dir,image))
    for block in result.pages[0].blocks:
        for line in block.lines:
            for word in line.words:
                values = []
                geo = word.geometry
                a = list(int(a*b) for a,b in zip(geo[0],dim))
                b = list(int(a*b) for a,b in zip(geo[1],dim))
                values.append("text")
                values.append(word.confidence)
                values.append(a[0])
                values.append(a[1])
                values.append(b[0]-a[0])
                values.append(b[1]-a[1])
                values.append(word.value)
                predictions.append(values)
                cv2.rectangle(img, (a[0], a[1]), (b[0], b[1]), (0, 255, 0))
    io.imsave(output_dir + 'images/' + image,img)
    total[image] = predictions
    
    
for image,result in tqdm(total.items()):
    name = image[:len(image) - 4]
    df = pd.DataFrame(result, columns = ['label', 'confidence', 'X', 'Y', 'W', 'H', 'prediction'])
    df.to_csv(output_dir + 'txt/' + name + '.txt', sep=' ',index=False, header=False)

with open(output_dir+'results.pkl', 'wb') as outp:  # Overwrites any existing file.
    pickle.dump(results, outp, pickle.HIGHEST_PROTOCOL)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:42<00:00,  2.05s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.40it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 791.63it/s]

# %% [markdown]
# ### Tesseract LF

# %%
from pytesseract import Output, image_to_data

input_dir   = './../../processed/docbank_100/images/'
output_dir  = './../../data/00_docbank_100/tesseract/'  

dir_list = os.listdir(input_dir)

dimensions = {}
results = {}
total = {}

for image in tqdm(dir_list):
    predictions = []
    img = cv2.imread(input_dir + image)
    d = image_to_data(img, output_type=Output.DICT)
    for i in range(len(d['level'])):
        if d['level'][i]==5:
            values = []
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            (x, y, w, h) = (int(x), int(y), int(w), int(h))
            values.append('text')
            values.append(d['conf'][i])
            values = values + [x,y,w,h]
            values.append(d['text'][i])
            if(x==0 and y==0):
                continue
            else:
                cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255))
            predictions.append(values)
    total[image] = predictions
    results[image] = d
    cv2.imwrite(output_dir + 'images/' + image, img)

for image,result in total.items():
    name = image[:len(image) - 4]
    df = pd.DataFrame(result, columns = ['label', 'confidence', 'X', 'Y', 'W', 'H', 'prediction'])
    df.to_csv(output_dir + 'txt/' + name + '.txt', sep=' ',index=False, header=False)

with open(output_dir+'results.pkl', 'wb') as outp:  # Overwrites any existing file.
    pickle.dump(results, outp, pickle.HIGHEST_PROTOCOL)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:47<00:00,  1.05it/s]
